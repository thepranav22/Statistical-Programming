# %%
from random import seed 
from numpy.random import randint
from numpy import mean

#from cupy.random import seed
#from cupy.random import randint
#from cupy import mean
import random
import numpy as cp
import time
from matplotlib import pyplot

# %%
start=time.time()
means=[cp.mean(randint(1,7,10000)) for _ in range(1000)]
seed(1)
end=time.time()
print("Time taken:",end-start)
# Out:
# Time taken: 0.15483808517456055

# %%
pyplot.hist(means,bins=10)
pyplot.show()

# %%
from random import seed 
from random import random
from numpy import mean
import random
import numpy as np
import time
import random
from numpy import arange
from scipy.stats import norm
from matplotlib import pyplot
l=[]
m=[]
for i in range(0,1000):
  l=[]
  for j in range(0,10000):
    l.append(random.randint(1,6))
  m.append(mean(l))
pyplot.hist(m,bins=100)
pyplot.show()
x=arange(-4,4,0.001)
y=norm.pdf(x,0,1)
pyplot.plot(x,y)
