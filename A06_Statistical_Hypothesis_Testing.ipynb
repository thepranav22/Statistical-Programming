# %%
from random import seed 
from random import random
from numpy import mean
from numpy.random import randint
from numpy.random import binomial
import random
import numpy as np
import time
from matplotlib import pyplot
import scipy.stats as stats

# %%
data=[300,315,320,311,314,309,300,308,305,301,303]

#perform one sample t-test
stats.ttest_1samp(a=data,popmean=315)
# Out:
# Ttest_1sampResult(statistic=-3.552221473370639, pvalue=0.00524878839447635)

# %%
from scipy.stats.stats import ttest_ind
samp1=[300,315,320,311,314,309,300,308,305,303,305,301,303]
samp2=[335,329,322,321,324,319,304,308,305,311,307,300,305]

#perform two sample t-test
ttest_ind(samp1,samp2)
# Out:
# Ttest_indResult(statistic=-2.1009029257555696, pvalue=0.04633501389516516)

# %%
before=[22,24,20,19,19,20,22,23,24,23,22,21]
after=[23,25,20,19,19,22,23,28,24,24,24,20]

#perform two sample t-test
stats.ttest_rel(before,after)
# Out:
# Ttest_relResult(statistic=-2.253202848596432, pvalue=0.04563290678724982)
